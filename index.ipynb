# %%
import numpy as np
import pandas as pd
import collections 
import seaborn as sns
from sklearn import datasets
import matplotlib.pyplot as plt

# %%
heart_disease_patients = pd.read_csv("heart_disease_patients.csv")

# %%
heart_disease_patients.head()
# Out:
#    id  age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak
# 0   1   63    1   1       145   233    1        2      150      0      2.3  \
# 1   2   67    1   4       160   286    0        2      108      1      1.5
# 2   3   67    1   4       120   229    0        2      129      1      2.6
# 3   4   37    1   3       130   250    0        0      187      0      3.5
# 4   5   41    0   2       130   204    0        2      172      0      1.4
#
#    slope
# 0      3
# 1      2
# 2      2
# 3      3
# 4      1

# %%
heart_disease_patients.tail()
# Out:
#       id  age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak
# 298  299   45    1   1       110   264    0        0      132      0      1.2  \
# 299  300   68    1   4       144   193    1        0      141      0      3.4
# 300  301   57    1   4       130   131    0        0      115      1      1.2
# 301  302   57    0   2       130   236    0        2      174      0      0.0
# 302  303   38    1   3       138   175    0        0      173      0      0.0
#
#      slope
# 298      2
# 299      2
# 300      2
# 301      2
# 302      1

# %%
heart_disease_patients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        303 non-null    int64
#  1   age       303 non-null    int64
#  2   sex       303 non-null    int64
#  3   cp        303 non-null    int64
#  4   trestbps  303 non-null    int64
#  5   chol      303 non-null    int64
#  6   fbs       303 non-null    int64
#  7   restecg   303 non-null    int64
#  8   thalach   303 non-null    int64
#  9   exang     303 non-null    int64
#  10  oldpeak   303 non-null    float64
#  11  slope     303 non-null    int64
# dtypes: float64(1), int64(11)
# memory usage: 28.5 KB

# %%
heart_disease_patients.describe()
# Out:
#                id         age         sex          cp    trestbps        chol
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000  \
# mean   152.000000   54.438944    0.679868    3.158416  131.689769  246.693069
# std     87.612784    9.038662    0.467299    0.960126   17.599748   51.776918
# min      1.000000   29.000000    0.000000    1.000000   94.000000  126.000000
# 25%     76.500000   48.000000    0.000000    3.000000  120.000000  211.000000
# 50%    152.000000   56.000000    1.000000    3.000000  130.000000  241.000000
# 75%    227.500000   61.000000    1.000000    4.000000  140.000000  275.000000
# max    303.000000   77.000000    1.000000    4.000000  200.000000  564.000000
#
#               fbs     restecg     thalach       exang     oldpeak       slope
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.148515    0.990099  149.607261    0.326733    1.039604    1.600660
# ...

# %%
heart_disease = heart_disease_patients

# %%
import missingno as msno
p=msno.bar(heart_disease)

# %%
fig,ax = plt.subplots(nrows = 2, ncols=2, figsize=(16,10))
row = 0
col = 0
for i in range(len(heart_disease.columns) -1):
    if col > 1:
        row += 1
        col = 0
    axes = ax[row,col]
    sns.boxplot(x = heart_disease['trestbps'], y = heart_disease[heart_disease.columns[i]],ax = axes)
    col += 1
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 8
#       6     row += 1
#       7     col = 0
# ----> 8 axes = ax[row,col]
#       9 sns.boxplot(x = heart_disease['trestbps'], y = heart_disease[heart_disease.columns[i]],ax = axes)
#      10 col += 1
#
# IndexError: index 2 is out of bounds for axis 0 with size 2

# %%
sns.countplot(y=heart_disease.trestbps ,data=heart_disease)
plt.xlabel("sex")
plt.ylabel("trestbps")
plt.show()

# %%
p=sns.pairplot(heart_disease, hue = 'trestbps')

# %%
plt.figure(figsize=(15,15))
p=sns.heatmap(heart_disease.corr(), annot=True,cmap='RdYlGn')

# %%
heart_disease.hist(figsize=(15,12),bins = 15)
plt.title("Features Distribution")
plt.show()

# %%
X = heart_disease.drop(['trestbps'],axis=1)
y = heart_disease.trestbps
